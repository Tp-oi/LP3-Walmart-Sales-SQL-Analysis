# %%
print("Hello world.")
# Out:
# Hello world.

# %%
import zipfile

with zipfile.ZipFile("walmart-10k-sales-datasets.zip", 'r') as zip_ref:
    zip_ref.extractall("walmart_sales")

print("Unzipping complete!")
# Out:
# Unzipping complete!

# %%
import pandas as pd #pandas is a data manipulation library

#import pymysql  #import the mysql database driver
from sqlalchemy import create_engine #sqlalchemy is a sql toolkit and Object Relational Mapper

import psycopg2 #import the postgresql database driver

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
df = pd.read_csv('walmart_sales\Walmart.csv', encoding_errors='ignore')

df.shape
# Out:
# (10051, 11)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(51)

# %%
df.drop_duplicates(inplace=True)    # drop duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.dropna(inplace=True)    # drop missing values
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price         object
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df['unit_price']=df['unit_price'].str.replace('$','').astype(float)
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price        float64
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %%
df['total'] = df['unit_price'] *df['quantity']  # create a new column
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'total'],
#       dtype='object')

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price        float64
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# total             float64
# dtype: object

# %%
df.to_csv('walmart_clean_data.csv', index=False)    # export cleaned data set out

# %%
engine = create_engine('postgresql+psycopg2://')    # connect to server

# %%
engine_psql = create_engine('postgresql+psycopg2://postgres:x0000@localhost:5432/walmart_db')    # connect to server

try:
    engine_psql
    print("Connection to PostgreSQL DB successful")
except:
    print("Connection to PostgreSQL DB not successful")  # check if connection is successful
# Out:
# Connection to PostgreSQL DB successful

# %%
df.columns = df.columns.str.lower()
df.columns
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17

# %%
df.to_sql(name='walmart_sales', con=engine_psql, if_exists='replace', index=False)    # write data to table
# Out:
# 969

# %%
df = pd.read_sql("SELECT city, rating FROM walmart_sales;", con=engine_psql)    # read data from table
df.head()
# Out:
#           city  rating
# 0  San Antonio     9.1
# 1    Harlingen     9.6
# 2  Haltom City     7.4
# 3      Bedford     8.4
# 4       Irving     5.3

# %%
from scipy.stats import ttest_1samp

# Calculate the national average rating
national_avg = df['rating'].mean()

# Loop through each city and test
results = []
for city, group in df.groupby('city'):
    t_stat, p_value = ttest_1samp(group['rating'], popmean=national_avg)
    results.append({
        'city': city,
        'store_avg': group['rating'].mean(),
        't_stat': t_stat,
        'p_value': p_value
    })

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Optional: flag significance
results_df['significant'] = results_df['p_value'] < 0.05

# Add a new column to classify stores
results_df['group'] = results_df.apply(
    lambda row: 'Above Average' if row['significant'] and row['store_avg'] > national_avg 
    else ('Below Average' if row['significant'] and row['store_avg'] < national_avg 
    else 'Not Significant'),
    axis=1
)

# Display the grouped results
above_avg = results_df[results_df['group'] == 'Above Average']
below_avg = results_df[results_df['group'] == 'Below Average']

# Show results
print("National Average Rating:", national_avg)
print("\n--- Stores Significantly Above Average ---")
display(above_avg)

print("\n--- Stores Significantly Below Average ---")
display(below_avg)
# Out:
# National Average Rating: 5.828839402146654
#
# --- Stores Significantly Above Average ---
#                city  store_avg    t_stat       p_value  significant  \
# 0           Abilene   6.336111  2.599907  1.133612e-02         True
# 1             Alamo   6.595588  3.450362  9.733294e-04         True
# 3             Allen   6.389041  2.724514  8.077244e-03         True
# 4          Amarillo   6.542308  2.793862  7.318716e-03         True
# 5          Angleton   6.361194  2.595982  1.161446e-02         True
# 7            Austin   7.001667  6.353958  3.320059e-08         True
# 8           Baytown   6.215000  2.006601  4.821364e-02         True
# 9           Bedford   6.331250  2.076044  4.197636e-02         True
# 10       Big Spring   6.449398  3.552070  6.367475e-04         True
# 11      Brownsville   6.588571  3.703182  4.249478e-04         True
# 12        Brownwood   6.492105  3.553551  6.615919e-04         True
# ...
